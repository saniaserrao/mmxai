# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModel
import os
import sys
import pickle
from tqdm.auto import tqdm

sys.path.append(os.path.abspath("../src"))

# %%
from extract_features import extract_linguistic_features, extract_acoustic_features

# %%
train_data_dir = "../data/train.csv"
test_data_dir = "../data/test.csv"
output_dir = "../data/bert_embeddings"
acoustic_output_dir="../data/mel_spectrograms"

# %%
extract_linguistic_features(train_data_dir, output_dir)
# Out:
# Load BERT tokenizer and model :bert-base-uncased --->
# Reading data file: ../data/train.csv...
# Processing 1447 transcriptions in batches of 32 --->
# Encoding Progress: 100%|██████████| 46/46 [00:13<00:00,  3.51it/s]
# Saving 1447 embeddings to ../data/bert_embeddings\train_bert_embeddings.pkl...
# BERT encoding and saving complete!
# Example embedding shape: (128, 768)
# Example embedding for ID 0:
#   Transcription: 'show my latest transactions'
#   Embedding shape: (128, 768)

# %%
extract_linguistic_features(test_data_dir, output_dir)
# Out:
# Load BERT tokenizer and model :bert-base-uncased --->
# Reading data file: ../data/test.csv...
# Processing 362 transcriptions in batches of 32 --->
# Encoding Progress: 100%|██████████| 12/12 [00:03<00:00,  3.70it/s]
# Saving 362 embeddings to ../data/bert_embeddings\test_bert_embeddings.pkl...
# BERT encoding and saving complete!
# Example embedding shape: (128, 768)
# Example embedding for ID 0:
#   Transcription: 'Uncle freeze my card'
#   Embedding shape: (128, 768)

# %%
extract_acoustic_features(train_data_dir, acoustic_output_dir)
# Out:
# c:\research_mmxai\.venv\lib\site-packages\torchaudio\functional\functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (201) may be set too low.
#   warnings.warn(
# Processing 1447 audio files...
# Extracting Mel Spectrograms: 100%|██████████| 1447/1447 [00:03<00:00, 391.98it/s]
# Saving 1447 Mel spectrograms to ../data/mel_spectrograms\train_mel_spectrograms.pkl...
# Mel spectrogram extraction and saving complete!
#  Example Mel spectrogram shape: (128, 743)
#  Example Mel spectrogram for ID 0:
#   Audio Path: '../data/MInDS-14\audio\en-US~LATEST_TRANSACTIONS/602baeea963e11ccd901ce14.wav'
#   SR: 16000Hz
#   Duration: 7.42s

# %%
extract_acoustic_features(test_data_dir, acoustic_output_dir)
# Out:
# c:\research_mmxai\.venv\lib\site-packages\torchaudio\functional\functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (201) may be set too low.
#   warnings.warn(
# Processing 362 audio files...
# Extracting Mel Spectrograms: 100%|██████████| 362/362 [00:00<00:00, 522.64it/s]
# Saving 362 Mel spectrograms to ../data/mel_spectrograms\test_mel_spectrograms.pkl...
# Mel spectrogram extraction and saving complete!
#  Example Mel spectrogram shape: (128, 325)
#  Example Mel spectrogram for ID 0:
#   Audio Path: '../data/MInDS-14\audio\en-US~FREEZE/602bac7e5f67b421554f6484.wav'
#   SR: 16000Hz
#   Duration: 3.24s
